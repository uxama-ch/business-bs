# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# Collecting pygit2==1.15.1
#   Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pygit2==1.15.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (2.22)
# Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 22.8 MB/s eta 0:00:00
# Installing collected packages: pygit2
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.17.0
#     Uninstalling pygit2-1.17.0:
#       Successfully uninstalled pygit2-1.17.0
# Successfully installed pygit2-1.15.1
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Counting objects: 100% (1408/1408), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 6725 (delta 1351), reused 1260 (delta 1260), pack-reused 5317 (from 1)
# Receiving objects: 100% (6725/6725), 33.19 MiB | 28.70 MiB/s, done.
# Resolving deltas: 100% (3928/3928), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 13.3MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 9.36MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 82.7MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:01<00:00, 323MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/juggernautXL_v8Rundiffusion.safetensors" to /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
#
# 100% 6.62G/6.62G [00:42<00:00, 166MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors" to /content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors
#
# 100% 47.3M/47.3M [00:00<00:00, 270MB/s]
# Total VRAM 15095 MB, total RAM 12978 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://3a59b7d6519386f932.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.61 seconds
# 2025-04-25 04:36:51.535877: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745555811.766186    1788 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745555811.832504    1788 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-25 04:36:52.342392: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 764
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://3a59b7d6519386f932.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 2527268173864793003
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] elf in pakistan, light, strong, crisp, extremely detailed, artistic, cinematic, complex, highly color, still, dynamic, ambient, elegant, intricate, majestic, thought, magic, dramatic, sharp focus, professional, winning, smart, creative,, very inspirational, innocent, generous, vibrant, epic, glorious, illuminated, brilliant, beautiful, perfect
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] elf in pakistan, cinematic, stunning, highly detailed, incredible quality, inspired, very inspirational, intricate, epic composition, still, crisp, full color, elegant, designed, complex, fine detail, professional, ambient background, dynamic light, magic, scenic, elite, illuminated, amazing, creative, positive, wonderful, pure, attractive, passionate, beautiful, confident
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 3.69 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.74 seconds
# 100% 30/30 [00:26<00:00,  1.11it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.35 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-25/log.html
# Generating and saving time: 31.84 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.64 seconds
# 100% 30/30 [00:27<00:00,  1.07it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-25/log.html
# Generating and saving time: 31.60 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 63.44 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 67.19 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.81 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 3159953793304730335
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] anime style school girl looking at a boy across the hallway, light, stunning, highly detailed, true magic, great composition, dramatic beautiful, intricate, elegant, sharp focus, perfect fine detail, professional, ambient, cinematic, fancy, artistic, best, grand, shining, complex, modern, fantastic, cool, creative, vibrant color, cute, amazing, awesome
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] anime style school girl looking at a boy across the hallway, light taking focus, highly detailed, sharp focused, elegant, perfect composition, dramatic cinematic, fine detail, joyful, intricate, innocent, aesthetic, very inspirational, professional, stunning, saturated colors, inspired, pretty, confident, epic, artistic, background composed, iconic, grand illumination, bright color, best
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 2.52 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.23 seconds
# 100% 30/30 [00:27<00:00,  1.09it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-25/log.html
# Generating and saving time: 31.76 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.62 seconds
# 100% 30/30 [00:27<00:00,  1.08it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.33 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-25/log.html
# Generating and saving time: 31.29 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 63.05 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 65.64 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.81 seconds
# Loaded preset: /content/Fooocus/presets/anime.json
# Downloading: "https://huggingface.co/mashb1t/fav_models/resolve/main/fav/animaPencilXL_v500.safetensors" to /content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors
#
# 100% 6.46G/6.46G [00:31<00:00, 221MB/s]
# Enter LCM mode.
# [Fooocus] Downloading LCM components ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/sdxl_lcm_lora.safetensors" to /content/Fooocus/models/loras/sdxl_lcm_lora.safetensors
#
# 100% 376M/376M [00:06<00:00, 64.7MB/s]
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 3127489293310248556
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = lcm - lcm
# [Parameters] Steps = 8 - 8
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.74 seconds
# Base model loaded: /content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors
# VAE loaded: None
# Request to load LoRAs [('sdxl_lcm_lora.safetensors', 1.0)] for model [/content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sdxl_lcm_lora.safetensors] for UNet [/content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors] with 788 keys at weight 1.0.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.80 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] anime style school girl looking at a boy across the hallway, light flashing, beautiful composition, intricate, elegant, sharp focus, highly detailed, cinematic, complex, glowing, rich bright, colorful, true colors, inspired, innocent, full color, deep aesthetic, very inspirational, cute, fine detail, clear artistic, novel, intriguing, unique, attractive, pretty, iconic
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] anime style school girl looking at a boy across the hallway, light magic, dramatic ambient, highly detailed, professional quality, real, fine detail, sharp focus, intricate, rich deep colors, perfect, dynamic, vibrant complex, great composition, elegant, confident, vivid, awesome background, cinematic, artistic, enhanced, best, creative, amazing, brilliant, beautiful, symmetry
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1152, 896)
# Preparation time: 50.97 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.39970144629478455, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.66 seconds
# 100% 8/8 [00:03<00:00,  2.24it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.32 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-25/log.html
# Generating and saving time: 8.16 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.39970144629478455, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.70 seconds
# 100% 8/8 [00:03<00:00,  2.25it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-25/log.html
# Generating and saving time: 7.00 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 15.16 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 66.18 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.79 seconds
# Enter LCM mode.
# [Fooocus] Downloading LCM components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 2046377886436739737
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = lcm - lcm
# [Parameters] Steps = 8 - 8
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] girl looking at a boy across the hallway in school, fine detail, vibrant colors, very strong, dramatic light, cinematic, complex, detailed, stunning composition, highly saturated color, ambient background, sharp focus, epic, enigmatic, beautiful, elegant, located deep rich vivid, colorful, excellent, professional, artistic, successful, romantic, inspirational, thoughtful, confident, pretty
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] girl looking at a boy across the hallway in school, dynamic composition, dramatic light, aesthetic, elegant, fine detail, highly detailed, clear focus, intricate, innocent, inspired, rich deep vivid color, cinematic, smart, artistic, sharp, hopeful, vibrant colors, optimistic, glowing, professional, enhanced, extremely creative, cheerful, beautiful, symmetry, determined, passionate
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1152, 896)
# Preparation time: 1.72 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.39970144629478455, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.31 seconds
# 100% 8/8 [00:03<00:00,  2.23it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-25/log.html
# Generating and saving time: 7.73 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.39970144629478455, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.70 seconds
# 100% 8/8 [00:03<00:00,  2.19it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-25/log.html
# Generating and saving time: 7.40 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 15.12 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 16.90 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.83 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/sdxl_lightning_4step_lora.safetensors" to /content/Fooocus/models/loras/sdxl_lightning_4step_lora.safetensors
#
# 100% 376M/376M [00:01<00:00, 306MB/s]
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 4257068695243298251
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [('sdxl_lightning_4step_lora.safetensors', 1.0)] for model [/content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sdxl_lightning_4step_lora.safetensors] for UNet [/content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors] with 788 keys at weight 1.0.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.27 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] girl looking at a boy across the hallway in school, highly detailed, sharp focus, dramatic, cinematic, candid, intricate, elegant, full color, very inspirational, gorgeous, inspiring, thought, magic, glowing, magical atmosphere, professional, awarded, best, creative, positive, joyful, unique, beautiful, confident, shiny, perfect, focused, cute, pretty, inspired
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] girl looking at a boy across the hallway in school, classic composition, sharp focus, detailed, still, highly intricate, elegant, creative, color spread, symmetry, cinematic, unique, fine detail, professional, artistic, best, fair, light, clear, crisp, extremely aesthetic, glowing, rich, hopeful, shiny, bright, true colors, perfect, colorful, rational
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1152, 896)
# Preparation time: 5.22 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.24 seconds
# 100% 4/4 [00:01<00:00,  2.17it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-25/log.html
# Generating and saving time: 5.95 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.70 seconds
# 100% 4/4 [00:01<00:00,  2.13it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-25/log.html
# Generating and saving time: 5.64 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 11.58 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 16.85 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.90 seconds
